# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

# %%
x = np.linspace(0.001,50 * np.pi,5000)
y = x**2.5

# %%
@interact
def p(pot=0.5):
	x = np.linspace(0.001,50 * np.pi,5000)
	y = x**pot
	plt.polar(x,y)
	plt.show()
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
